# %%
import seaborn as sb
import sys  
import pandas as pd
import requests
import numpy as np
import datetime
import time
import pickle
import matplotlib.pyplot as plt
import time
# %matplotlib inline

from bs4 import BeautifulSoup as bs
import urllib

# %%
from bs4 import BeautifulSoup
import re
import string
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.preprocessing import LabelEncoder
from scipy.sparse import csr_matrix, hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from scipy import sparse
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score
from sklearn.svm import SVR
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from random import sample 

from tqdm import tqdm
import nltk
from pymorphy2 import MorphAnalyzer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\viktoria.sinditskaya\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
df = load_obj('data_clean_df')

# %%
df.head()
# Out:
#                                                about  \
# 1
# 4
# 5  🏷Концерты (букинг) +7 985 226 7676\n🛍Реклама/P...
# 7  По вопросам организации концертов:\n\nПо вопро...
# 9
#
#                                       activities age_cat       bdate  \
# 1                                        актриса   30_40  14.11.1984
# 4                                                  30_40        12.4
# 5  Лена Темникова — популярная российская певица   30_40        18.4
# 7                       певица, актриса, ведущая   30_40         1.3
# 9                                                  30_40   12.5.1987
#
#                                     books  can_access_closed    city country  \
# 1                                                       True  Moscow  Russia
# 4                                                       True  Moscow  Russia
# 5                                                       True  Moscow  Russia
# 7  Ги де Мопассан, Конфуций, Борис Акунин               True  Moscow  Russia
# 9                                                       True  Moscow  Russia
#
#   education_form education_status                   faculty_name  \
# 1
# 4
# 5
# 7                                  Факультет физической культуры
# 9
#
#    followers_count games  graduation  has_mobile home_town         id  \
# 1           939222                 0           1    Москва   45269508
# 4           536139                -1           1            314833033
# 5           528028                 0           1            243556640
# 7           450821                 0           1    Москва  164542053
# 9           376624                -1           1             81133993
#
#   interests  is_closed                                             movies  \
# 1                False
# 4                False
# 5                False
# 7                False  "Служебный роман", "Зеленая миля", "Человек, к...
# 9                False
#
#                                         music  occupation quotes  relation  \
# 1                                              university                0
# 4                                                    work               -1
# 5                                                    work                4
# 7  Beyonce, Shakira, Алла Пугачева, Уматурман  Не указано                0
# 9                                                    work               -1
#
#    sex                                         track_code  \
# 1    1  b2842eb9f_rndxNFGDYLHVpek0wfI0VPeH7_L2UIFO-0uq...
# 4    1  434bbf0afpE6Ldd9Egf_m5ep42e8CuSMprLVXk-3KngDNZ...
# 5    1  d41b43eaWtMJH9O5e15g3fJZXHfTvmlXuJZi5BDHDqmFUD...
# 7    1  58518e8cqBV_N0KD2JTXIVRWQxh6zZwmEzAV2OmZuWBKdK...
# 9    1  97803050Z599F6OhYv1wh-5wesMApIgG1QQW0dhxiKXNPz...
#
#             university_name  verified   political       langs    religion  \
# 1                     ГИТИС         1  Не указано  Не указано  Не указано
# 4                                   1  Не указано  Не указано  Не указано
# 5                                   1  Не указано   [Русский]  Не указано
# 7  МГАФК (Мосспортакадемия)         1  Не указано   [Русский]  Не указано
# 9                                   1  Не указано  Не указано  Не указано
#
#   inspired_by people_main life_main     smoking     alcohol schools_name  \
# 1  Не указано  Не указано            Не указано  Не указано
# 4  Не указано  Не указано            Не указано  Не указано
# 5  Не указано  Не указано            Не указано  Не указано
# 7  Не указано  Не указано            Не указано  Не указано
# 9  Не указано  Не указано            Не указано  Не указано
#
#   schools_grad_year  has_facebook  has_instagram  has_livejournal  \
# 1                               0              0                0
# 4                               0              0                0
# 5                               0              1                0
# 7                               0              0                0
# 9                               0              0                0
#
#    has_twitter  has_skype  has_relative
# 1            1          0             1
# 4            0          0             1
# 5            0          0             1
# 7            0          0             1
# 9            1          0             1

# %%
numrc_col = [x for x in df.columns if df[x].dtype == 'float64' or df[x].dtype == 'int64']

# %%
df[numrc_col].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 1 to 3895
# Data columns (total 13 columns):
# followers_count    860 non-null int64
# graduation         860 non-null int64
# has_mobile         860 non-null int64
# id                 860 non-null int64
# relation           860 non-null int64
# sex                860 non-null int64
# verified           860 non-null int64
# has_facebook       860 non-null int64
# has_instagram      860 non-null int64
# has_livejournal    860 non-null int64
# has_twitter        860 non-null int64
# has_skype          860 non-null int64
# has_relative       860 non-null int64
# dtypes: int64(13)
# memory usage: 94.1 KB

# %%
str_col = [x for x in df.columns if df[x].dtype == 'object']

# %%
wall = load_obj('users_wall_posts')

# %%
len(wall)
# Out:
# 482

# %%
chrs_to_delete = string.punctuation + u'»' + u'«' + u'—' + u'“' + u'„' + u'•' + u'#'
translation_table = {ord(c): None for c in chrs_to_delete if c != u'-'}
units = MorphAnalyzer.DEFAULT_UNITS
morph = MorphAnalyzer(result_type=None, units=units)
PortSt = PorterStemmer()
stopw = set(
    [w for w in stopwords.words(['russian', 'english'])]
    + [u'это', u'году', u'года', u'также', u'етот',
    u'которые', u'который', u'которая', u'поэтому',
    u'весь', u'свой', u'мочь', u'eтот', u'например',
    u'какой-то', u'кто-то', u'самый', u'очень', u'несколько',
    u'источник', u'стать', u'время', u'пока', u'однако',
    u'около', u'немного', u'кроме', u'гораздо', u'каждый',
    u'первый', u'вполне', u'из-за', u'из-под',
    u'второй', u'нужно', u'нужный', u'просто', u'большой',
    u'хороший', u'хотеть', u'начать', u'должный', u'новый', u'день',
    u'метр', u'получить', u'далее', u'именно', u'апрель',
    u'сообщать', u'разный', u'говорить', u'делать',
    u'появиться', u'2016',
    u'2015', u'получить', u'иметь', u'составить', u'дать', u'читать',
    u'ничто', u'достаточно', u'использовать',
    u'принять', u'практически',
    u'находиться', u'месяц', u'достаточно', u'что-то', u'часто',
    u'хотеть', u'начаться', u'делать', u'событие', u'составлять',
    u'остаться', u'заявить', u'сделать', u'дело',
    u'примерно', u'попасть', u'хотя', u'лишь', u'первое',
    u'больший', u'решить', u'число', u'идти', u'давать', u'вопрос',
    u'сегодня', u'часть', u'высокий', u'главный', u'случай', u'место',
    u'конец', u'работать', u'работа', u'слово', u'важный', u'сказать']
)
url_start = 'http[s]?://'
url_end = (
    '(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
)
pattern = url_start + url_end

# %%
users_clean_wall_dict = {}
counter = 0

for user_id, doc in wall.items():
    try:
        soup = BeautifulSoup(doc, 'html.parser')
        body = ' '.join(
            [tag.string.replace('\\n', ' ').replace('\\r', ' ')
            for tag in soup.descendants if tag.string]
        )
        body = re.sub('\[.*?\]','', body)
        body = re.sub(pattern,'', body)
    except Exception as ex:

        print('Unable to parse posts of user {}'.format(user_id))
    if body != '':
        body_clean = body.translate(translation_table).lower().strip()
        #токенизируем текст (грубо говоря, разбиваем на слова)
        words = word_tokenize(body_clean)
        tokens = []
        # stemming and text normalization
        for word in words:
            if re.match('^[a-z0-9-]+$', word) is not None:
                #если токен попадает под паттерн английского слова или цифры - делаем стемминг
                tokens.append(PortSt.stem(word))
            elif word.count('-') > 1:
                #если токен представляет собой набор символов --- , которые мы не удаляли, так как он может входить в слово ефис, просто добавляем это токен целиком
                tokens.append(word)
            else:
                #если токен русское слово - применяем к нему нормальную форму
                normal_forms =morph.normal_forms(word)
                tokens.append(normal_forms[0] if normal_forms else word)
        # remove stopwords and leave unique words only
        tokens = filter(
            lambda token: token not in stopw, sorted(set(tokens))
        )

        # leave all words with more than 3 chars
        tokens = filter(lambda token: len(token) > 3, tokens)
    else:
        tokens = []
    counter += 1
    if counter % 100 == 0:
        print("{0} docs processed".format(counter))
    #словарь, где id - это id группы, значения - ее очищенные токенизированные слова
    users_clean_wall_dict[user_id] = tokens
#словарь id группы: очищенные слова по ее постам
user_clean_doc_dict = {key: list(val) for key, val in users_clean_wall_dict.items()}
# Out:
# 100 docs processed
# 200 docs processed
# 300 docs processed
# 400 docs processed

# %%
def add_post(x):
    uid = x['id']
    try:
            post = user_clean_doc_dict[uid]
            return post
    except Exception:
            return

# %%
df['post'] = df.apply(lambda x:add_post(x),axis=1)

# %% [markdown]
# # Подготовка данных для модели

# %% [markdown]
# Для начала попробуем добавить дополнительные столбцы, которые могут помочь в определении возраста

# %% [markdown]
# Используем данные из столбца дата год окончания высшего учебного заведения и год окончания школы, чтобы как то определить примерный возраст

# %%
df.loc[df['schools_grad_year'] == '','schools_grad_year'] = -1
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
def get_avg_age_from_grad_dates(row):
    grad_school = int(row['schools_grad_year'])
    grad_uni = int(row['graduation'])
    years = []
    if grad_uni > 0:
        for year in range(21, 27):
            years.append(year + 2019 - grad_uni)
    if grad_school > 0:
        for year in range(17, 20):
            years.append(year + 2019 - grad_school)
    if len(years) != 0:
        return int(np.mean(years))
    else:
        return 0

# %%
df['guessed_age'] = df.apply(get_avg_age_from_grad_dates, axis=1)
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['guessed_age'].head()
# Out:
# 22     0
# 36     0
# 74     0
# 77     0
# 139    0
# Name: guessed_age, dtype: int64

# %%
df.head()
# Out:
#                                                  about            activities  \
# 22                                                                 Эзотерика
# 36
# 74
# 77   \n\nМОЯ  ГРУППА:\nhttp://vkontakte.ru/club1291...  Импрессионистическая
# 139                                                                  Актриса
#
#     age_cat      bdate                                              books  \
# 22    30_40  18.9.1988  *Анастасия-Влади́мир Мегре́ * Портрет Дориана ...
# 36    30_40   8.2.1989
# 74    30_40       14.3
# 77    30_40                                                       Научные
# 139   30_40  26.4.1989  Секрет, трансерфинг реальности, психология, би...
#
#      can_access_closed                     city  country education_form  \
# 22                True                  Tallinn  Estonia
# 36                True  Dnipropetrovsk (Dnipro)  Ukraine
# 74                True                   Moscow   Russia
# 77                True                     Kyiv  Ukraine
# 139               True                   Moscow   Russia
#
#     education_status faculty_name  followers_count      games  graduation  \
# 22                                          223979                      0
# 36                                          232554                     -1
# 74                                           50692                     -1
# 77                                           49489  Карточные           0
# 139                                          16689                      0
#
#      has_mobile  home_town         id              interests  is_closed  \
# 22            1    Раквере  156432930  фотография, Эзотерика      False
# 36            1               9562528                             False
# 74            1               2801899                             False
# 77            1  Тель-Авив   12113139          Вдохновляющие      False
# 139           1             468500574    Кино, Музыка, спорт      False
#
#            movies     music  occupation  \
# 22                           Не указано
# 36                           university
# 74                           Не указано
# 77   Исторические  Душевная  Не указано
# 139                                work
#
#                                                 quotes  relation  sex  \
# 22   “In order to experience everyday spirituality,...         0    1
# 36                                                            -1    1
# 74                                                            -1    1
# 77                                                             0    1
# 139                                                            1    1
#
#                                             track_code university_name  \
# 22   8b0ec723Vrcmg8oRplL3-ldLEyUBaAFrvjMXAgXUmhl1l2...
# 36   47a7d04a8ec6VLZTq2TqO_uuQOgIlk85KWcC6wsrDcmVci...
# 74   d83fb197braO8DtNw7wLF_vs7bPMHstqwSkUnCP-VzE2jP...
# 77   6be575180lQ2eXcG9dVYd9z_K6keeWMhxiTkZOi8MTaV1q...
# 139  96e7d5f9fAd7zOsx_4EDw4lvOeSlrmSSEfKd9PmxqPJ-ao...
#
#      verified   political                                  langs    religion  \
# 22          1  Не указано              [English, Eesti, Русский]  Не указано
# 36          0  Не указано                             Не указано  Не указано
# 74          1  Не указано                             Не указано  Не указано
# 77          1           3  [Русский, עברית, English, Українська]  Не указано
# 139         1  Не указано                              [Русский]  Не указано
#
#          inspired_by people_main life_main     smoking     alcohol  \
# 22        Не указано  Не указано            Не указано  Не указано
# 36        Не указано  Не указано            Не указано  Не указано
# 74        Не указано  Не указано            Не указано  Не указано
# 77   Все, что вокруг           6            Не указано  Не указано
# 139       Не указано  Не указано            Не указано  Не указано
#
#     schools_name schools_grad_year  has_facebook  has_instagram  \
# 22                              -1             0              0
# 36                              -1             1              1
# 74                              -1             0              0
# 77                              -1             0              1
# 139                             -1             0              0
#
#      has_livejournal  has_twitter  has_skype  has_relative  \
# 22                 0            0          0             1
# 36                 0            0          0             1
# 74                 0            0          0             1
# 77                 0            0          0             1
# 139                0            0          0             1
#
#                                                   post  guessed_age
# 22   [автор, администратор, адрес, бессонный, битва...            0
# 36   [100500, 27🎂всё, abscheck, beautyть, center, c...            0
# 74   [13-ий, 1530, 2017, 2018, 2100, 212vipwildpart...            0
# 77   [1085, 38098, 6-го, annaalkhim, artikselfmad, ...            0
# 139  [-быть, 1200-2100, 1600, 2000, 2011, 2018, 201...            0

# %% [markdown]
# Попробуем теперь извлечь данные из даты рождения

# %%
df['bdate']
# Out:
# 22       18.9.1988
# 36        8.2.1989
# 74            14.3
# 77
# 139      26.4.1989
# 171           11.5
# 962           15.8
# 964           21.1
# 971
# 978       8.5.1997
# 986           20.4
# 990      19.8.1998
# 992           30.6
# 995      13.1.1993
# 996
# 997      16.3.1999
# 998      18.9.1988
# 1001
# 1014           3.4
# 1015         16.12
# 1021          25.8
# 1023      8.2.1989
# 1032     20.8.1996
# 1035          20.7
# 1044     10.6.1999
# 1048
# 1052     30.8.1991
# 1056     26.3.1993
# 1071           8.9
# 1072         17.12
#            ...
# 3671     17.5.2003
# 3674     14.4.2001
# 3682          22.1
# 3689           1.3
# 3696
# 3697          16.2
# 3716          24.2
# 3718
# 3726           8.5
# 3740          16.9
# 3759         20.11
# 3774          5.12
# 3775           4.8
# 3778         17.11
# 3779           4.9
# 3782
# 3792      2.9.2002
# 3795      3.1.2003
# 3808          15.5
# 3809
# 3816     25.7.2000
# 3838           6.1
# 3840
# 3842     3.11.2001
# 3846     11.6.2000
# 3851          4.10
# 3854     15.4.2001
# 3865    20.10.2001
# 3879      6.5.2001
# 3895           2.5
# Name: bdate, Length: 356, dtype: object

# %%
def get_age_from_brthd(val):
    if val != '':
        if len(val.split('.')) == 3:
            return 2019 - int(val[-4:])
    return 0

# %%
df['guessed_age'] = df['bdate'].apply(get_age_from_brthd)
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Обработаем переменную типа занятости как указатель возраста: чем старше тип занятости - тем выше ранг переменной

# %%
rang_occupation = {'Не указано' : 0, 'work' : 3, 'university' : 2, 'school' : 1}
df['occupation'].replace(rang_occupation, inplace=True)
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df['occupation'].value_counts()
# Out:
# 0    168
# 3     99
# 2     71
# 1     18
# Name: occupation, dtype: int64

# %% [markdown]
# Теперь попробуем ввести некоторые бинарные признаки, которые будут характеризовать общую заполненность профиля. Исходим из предположения, что у более взрослых пользователей профиль менее заполнен. Выделим признаки, по которым будем смотреть заполнение и переменную, которая будет характеризовать степень заполненности

# %%
df.columns
# Out:
# Index(['about', 'activities', 'age_cat', 'bdate', 'books', 'can_access_closed',
#        'city', 'country', 'education_form', 'education_status', 'faculty_name',
#        'followers_count', 'games', 'graduation', 'has_mobile', 'home_town',
#        'id', 'interests', 'is_closed', 'movies', 'music', 'occupation',
#        'quotes', 'relation', 'sex', 'track_code', 'university_name',
#        'verified', 'political', 'langs', 'religion', 'inspired_by',
#        'people_main', 'life_main', 'smoking', 'alcohol', 'schools_name',
#        'schools_grad_year', 'has_facebook', 'has_instagram', 'has_livejournal',
#        'has_twitter', 'has_skype', 'has_relative', 'post', 'guessed_age'],
#       dtype='object')

# %%
#признаки для анализа
feat_completeness_lst = ['about', 'activities', 'books','games','has_mobile', 'home_town','interests','movies', 'music', 'quotes', 'relation', 'political', 'langs', 'religion', 'inspired_by',
       'people_main', 'life_main', 'smoking', 'alcohol','has_facebook', 'has_instagram', 'has_livejournal',
       'has_twitter', 'has_skype', 'has_relative']

# %%
df[ ['about', 'activities', 'books','games','has_mobile', 'home_town','interests','movies', 'music', 'quotes', 'relation', 'political', 'langs', 'religion', 'inspired_by',
       'people_main', 'life_main', 'smoking', 'alcohol','has_facebook', 'has_instagram', 'has_livejournal',
       'has_twitter', 'has_skype', 'has_relative']]
# Out:
#                                                   about  \
# 22
# 36
# 74
# 77    \n\nМОЯ  ГРУППА:\nhttp://vkontakte.ru/club1291...
# 139
# 171   *****************************************   \n...
# 962   ● Арт-директор\nart-director@nyusha.ru\n\n● PR...
# 964   http://instagram.com/kristydobro\n\n__________...
# 971          YouTube блогер Elli Di\nДобропорядочный =)
# 978   У меня только 1 аккаунт, остальные ФЕЙКИ! не в...
# 986
# 990   Привет всем!\nНедавно некоторые аккаунты были ...
# 992
# 995
# 996                      Скептик. Прагматик. Мизантроп.
# 997   https://www.youtube.com/user/GaleineBlogPost \...
# 998
# 1001
# 1014
# 1015
# 1021  http://ask.fm/Feofeo\nfeofeofeo.tumblr.com htt...
# 1023
# 1032  ПО-ПОВОДУ СОТРУДНИЧЕСТВА ПИСАТЬ НА МЫЛО\nkatya...
# 1035
# 1044  YOUTUBE:\nhttp://www.youtube.com/user/SvetaDer...
# 1048  Почта: Nastyaivlei@gmail.com (по работе)\n\nДо...
# 1052
# 1056
# 1071
# 1072
# ...                                                 ...
# 3671                                         🔥спросите🔥
# 3674
# 3682  Linkin Park soldier, параноик, социопат\nAdam ...
# 3689
# 3696
# 3697  Люблю маленьких детей Люблю лето, тёплый летни...
# 3716
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                                    ̅🅚̅🅡̅🅤̅🅣̅🅐̅🅨̅🅐̅
# 3779
# 3782
# 3792
# 3795
# 3808
# 3809
# 3816
# 3838
# 3840
# 3842
# 3846
# 3851
# 3854                          тупые люди,я вас ненавижу
# 3865
# 3879
# 3895
#
#                                              activities  \
# 22                                            Эзотерика
# 36
# 74
# 77                                 Импрессионистическая
# 139                                             Актриса
# 171                           Мечтать...Жить..и..Любить
# 962
# 964
# 971   Блогер Elli Di, помогаю понять собак и других ...
# 978
# 986
# 990
# 992
# 995
# 996     Актриса-бунтовка, национал-птеродактиль, кутила
# 997
# 998                                           Эзотерика
# 1001
# 1014
# 1015
# 1021  Осуществляю парикмахерские услуги (окрашивание...
# 1023
# 1032  ПО-ПОВОДУ СОТРУДНИЧЕСТВА ПИСАТЬ НА МЫЛО katyak...
# 1035  https://m.youtube.com/channel/UCVdetwo1VHNCiBg...
# 1044
# 1048           телеведущая, видеоблогер и просто топчик
# 1052
# 1056
# 1071
# 1072
# ...                                                 ...
# 3671                                            🔥зачем🔥
# 3674
# 3682
# 3689
# 3696
# 3697
# 3716
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                                           𝔫𝔬𝔬𝔬𝔬 𝔫𝔬
# 3779
# 3782
# 3792
# 3795                                Фикрайтер, фикридер
# 3808
# 3809
# 3816
# 3838
# 3840
# 3842
# 3846
# 3851
# 3854
# 3865
# 3879
# 3895
#
#                                                   books  \
# 22    *Анастасия-Влади́мир Мегре́ * Портрет Дориана ...
# 36
# 74
# 77                                              Научные
# 139   Секрет, трансерфинг реальности, психология, би...
# 171   Преступление и наказание, Мастер и Маргарита, ...
# 962
# 964
# 971   Робинзон Крузо, Три Мушкетера, Граф Монте-Крис...
# 978
# 986
# 990
# 992
# 995
# 996                                              Библия
# 997
# 998   *Анастасия-Влади́мир Мегре́ * Портрет Дориана ...
# 1001
# 1014
# 1015
# 1021
# 1023
# 1032                                             МЕМОСЫ
# 1035
# 1044
# 1048
# 1052
# 1056
# 1071
# 1072
# ...                                                 ...
# 3671                                          🍃палить?🍃
# 3674
# 3682                                 451° по Фаренгейту
# 3689
# 3696
# 3697         приключение тома сойера и гекльберри финна
# 3716
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                             ̅͠\n̅͠ภ̅͠Ծ̅͠Ϯ̅͠Ꮥ̅͠Ծ̅͠B
# 3779
# 3782
# 3792
# 3795
# 3808
# 3809
# 3816
# 3838
# 3840
# 3842
# 3846
# 3851                                               Жок😹
# 3854                                           не читаю
# 3865
# 3879
# 3895
#
#                                                   games  has_mobile  \
# 22                                                                1
# 36                                                                1
# 74                                                                1
# 77                                            Карточные           1
# 139                                                               1
# 171   собственная судьба и чужие чувства    ********...           1
# 962                                                               1
# 964                                                               1
# 971   The Sims 2, The Sims 3, The Sims 4 =) Call Of ...           1
# 978                                                               1
# 986                                                               1
# 990                                                               1
# 992                                                               1
# 995                                                               1
# 996                                             Ролевые           1
# 997                                                               1
# 998                                                               1
# 1001                                                              1
# 1014                                                              1
# 1015                                                              1
# 1021                                                              1
# 1023                                                              1
# 1032                                       НУ НАКАНЕЦТА           1
# 1035                                                              1
# 1044                                                              1
# 1048                                                              1
# 1052                                                              1
# 1056                                                              1
# 1071                                                              1
# 1072                                                              1
# ...                                                 ...         ...
# 3671                                            🔥надо?🔥           1
# 3674                                                              1
# 3682                                                              1
# 3689                                                              1
# 3696                                                              1
# 3697                                          Монополия           1
# 3716                                                              1
# 3718                                                              1
# 3726                                                              1
# 3740                                                              1
# 3759                                                              1
# 3774                                                              1
# 3775                                                              1
# 3778  ̅͠\n̅͠|̿ \͇|̅͠|͇̿ ͇̿ ͇̿|̅͠ ̿ ̿|̿ ̿ ̅͠ ͇ ͇\̿ ̿ ...           1
# 3779                                                              1
# 3782                                                              1
# 3792                                                              1
# 3795                 МАЙНКРАФТ ЭТО ЖИЗНЬ!!!1!!!!!)0))))           1
# 3808                                                              1
# 3809                                                              1
# 3816                                                              1
# 3838                                                              1
# 3840                                                              1
# 3842                                                              1
# 3846                                                              1
# 3851                                                              1
# 3854                                                              1
# 3865                                                              1
# 3879                                                              1
# 3895                                                              1
#
#                                               home_town  \
# 22                                              Раквере
# 36
# 74
# 77                                            Тель-Авив
# 139
# 171                                     Санкт-Петербург
# 962                                              Москва
# 964                                              Москва
# 971                                              Москва
# 978                                     Санкт-Петербург
# 986
# 990                                   Украина,Николаев.
# 992
# 995                                     Санкт-Петербург
# 996                                              Москва
# 997
# 998                                             Раквере
# 1001
# 1014
# 1015
# 1021                                           Владимир
# 1023
# 1032                      Харьков, Первомайский, Чугуев
# 1035            vika.addington@gmail.com сотрудничество
# 1044
# 1048
# 1052
# 1056
# 1071                                       Киев, Москва
# 1072
# ...                                                 ...
# 3671
# 3674
# 3682                                              Киото
# 3689                                   Украина, Харьков
# 3696
# 3697                                          Краснодар
# 3716  Kawasaki,Москва,Пермь,,Киров,Анапа,Туапсе,Чайк...
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                                          Нурсултан
# 3779
# 3782
# 3792
# 3795                                       Екатеринбург
# 3808                                          Белогорск
# 3809
# 3816  ♥→mลм г∂è πρท βсmρè५è г٥β٥ρяt ÅçČαגαmу Åגגèùќу...
# 3838
# 3840
# 3842                                                  -
# 3846                                            Харьков
# 3851                                            Ушарал💕
# 3854                                             Ржищев
# 3865
# 3879
# 3895
#
#                                               interests  \
# 22                                фотография, Эзотерика
# 36
# 74
# 77                                        Вдохновляющие
# 139                                 Кино, Музыка, спорт
# 171   Солнце...море...пляж...ходить по магазинам...м...
# 962
# 964
# 971   YouTube, SMM, SEO... Путешествия, яхтинг, вока...
# 978
# 986
# 990
# 992
# 995
# 996                                   Многообразие форм
# 997
# 998                               фотография, Эзотерика
# 1001
# 1014
# 1015
# 1021
# 1023
# 1032                                     ТАКС ТАКС ТАКС
# 1035           Сотрудничество  vika.addington@gmail.com
# 1044
# 1048
# 1052
# 1056
# 1071
# 1072
# ...                                                 ...
# 3671                                                🍃я🍃
# 3674
# 3682
# 3689
# 3696
# 3697                             Фортепиано, Флористика
# 3716
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                          🇩​🇪​🇻​🇰​🇦​ 🇰​🇷​🇺​🇹​🇦​🇾​🇦​
# 3779
# 3782
# 3792
# 3795                    Сериалы\кино, музыка, рисование
# 3808
# 3809
# 3816
# 3838
# 3840
# 3842
# 3846
# 3851
# 3854                                    страдать хуйнёй
# 3865
# 3879
# 3895
#
#                                                  movies  \
# 22
# 36
# 74
# 77                                         Исторические
# 139
# 171   Сладкий ноябрь, Прости за любовь, If only/Если...
# 962
# 964
# 971   Незнайка на луне, Один дома, терминал, Превосх...
# 978
# 986
# 990
# 992
# 995
# 996   "Убить Билла"; "В джазе только девушки"; "Крим...
# 997
# 998
# 1001
# 1014
# 1015
# 1021
# 1023
# 1032                                               МЕМЫ
# 1035
# 1044
# 1048
# 1052
# 1056
# 1071
# 1072
# ...                                                 ...
# 3671                                              🍃вам🍃
# 3674
# 3682  Сид и Нэнси, Пианист, Властелин колец, Скиф, 1...
# 3689
# 3696
# 3697              Малефисента, 3 метра над уровнем неба
# 3716
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                             ̅͠\n̅͠𝚗̅͠𝚘̅͠𝚝̅͠𝚜̅͠𝚘̅͠𝙱
# 3779
# 3782
# 3792
# 3795  Marvel, Гарри Поттер, 50 оттенков серого, На 5...
# 3808
# 3809
# 3816
# 3838
# 3840
# 3842
# 3846
# 3851                                        Ты мой дом🖤
# 3854
# 3865
# 3879
# 3895
#
#                                                   music  \
# 22
# 36
# 74
# 77                                             Душевная
# 139
# 171
# 962
# 964
# 971   Red Hot Chili Peppers, Metallica, Oliver Kolet...
# 978
# 986
# 990
# 992
# 995
# 996   Джаз, Блюз, Кантри, Панк-рок, Классика, Электр...
# 997
# 998
# 1001
# 1014
# 1015
# 1021
# 1023
# 1032                                      ЧТО ТУТ У НАС
# 1035
# 1044
# 1048
# 1052
# 1056
# 1071
# 1072
# ...                                                 ...
# 3671                                           🔥должна🔥
# 3674
# 3682  Rock., Mike Shinoda, Linkin Park, Three Days G...
# 3689
# 3696
# 3697                           Бетховен, Шуберт, Моцарт
# 3716                                               BASS
# 3718
# 3726
# 3740
# 3759
# 3774
# 3775
# 3778                           ̅🇹​̅🇭​̅🇪​̅ ̅🇴​̅🇳​̅🇱​̅🇾​̅
# 3779
# 3782
# 3792
# 3795  М83, Thirty seconds to mars, twenty one pilots...
# 3808
# 3809
# 3816
# 3838
# 3840
# 3842
# 3846
# 3851                                         QARAKESEK💕
# 3854                 зарубежная, грустная, танцевальная
# 3865
# 3879
# 3895
#
#                                                  quotes  relation   political  \
# 22    “In order to experience everyday spirituality,...         0  Не указано
# 36                                                             -1  Не указано
# 74                                                             -1  Не указано
# 77                                                              0           3
# 139                                                             1  Не указано
# 171   ♥ Нет ничего не справедливей, чем скучать по к...         1  Не указано
# 962                                                             0           3
# 964                                                             0  Не указано
# 971                                                             4  Не указано
# 978                                                             6  Не указано
# 986                                                            -1  Не указано
# 990                                                             0  Не указано
# 992                                                            -1  Не указано
# 995                                                             0  Не указано
# 996   "Единственное, что мешает мне учиться, — это п...         1           8
# 997                                                             0  Не указано
# 998   “In order to experience everyday spirituality,...         0  Не указано
# 1001                                                            1  Не указано
# 1014                                                           -1  Не указано
# 1015                                                           -1  Не указано
# 1021                                                            4  Не указано
# 1023                                                           -1  Не указано
# 1032  Йо йо йо 1483 да 369 Альбукерке жжот чё-каво с...         0  Не указано
# 1035                                                            0  Не указано
# 1044                                                            0           4
# 1048                                                            0  Не указано
# 1052                                                           -1  Не указано
# 1056                                                           -1  Не указано
# 1071                                                            1           3
# 1072                                                           -1  Не указано
# ...                                                 ...       ...         ...
# 3671                                             🍃сами🍃         5  Не указано
# 3674                                                           -1  Не указано
# 3682  Иисус не хочет превратить меня в солнечный луч...         6           3
# 3689                                                            0  Не указано
# 3696                                                           -1  Не указано
# 3697   Все дети мира плачут на одном языке. (Л. Леонов)         0  Не указано
# 3716                                                            4           3
# 3718                                                           -1  Не указано
# 3726                                                            0  Не указано
# 3740                                                           -1  Не указано
# 3759                                                            0  Не указано
# 3774                                                           -1  Не указано
# 3775                                                           -1  Не указано
# 3778                             ̅͠\n̅͠ᑎ̅͠❤̅͠Ƭ̅͠S̅͠❤̅͠ß         4           7
# 3779                                                            4  Не указано
# 3782                                                            1  Не указано
# 3792                                                           -1  Не указано
# 3795  Семья не заканчивается кровью, но и не начинае...         6  Не указано
# 3808                                                            8  Не указано
# 3809                                                           -1  Не указано
# 3816                                                            0  Не указано
# 3838                                                           -1  Не указано
# 3840                                                           -1  Не указано
# 3842                                                            6  Не указано
# 3846  \nЖивите в настоящем.\nБудьте счастливы.\nДума...         6  Не указано
# 3851  Біздің өмірімізде неше түрлі эмоцияларға толы ...         7  Не указано
# 3854                              моя жизнь-мои правила         0  Не указано
# 3865                                                           -1  Не указано
# 3879                                                           -1  Не указано
# 3895                                                           -1  Не указано
#
#                                          langs         religion  \
# 22                   [English, Eesti, Русский]       Не указано
# 36                                  Не указано       Не указано
# 74                                  Не указано       Не указано
# 77       [Русский, עברית, English, Українська]       Не указано
# 139                                  [Русский]       Не указано
# 171                                  [Русский]      Верю в себя
# 962                                  [Русский]       Не указано
# 964                                  [Русский]       Не указано
# 971                         [Русский, English]       Не указано
# 978               [Русский, English, Français]       Не указано
# 986                                 Не указано       Не указано
# 990    [Русский, English, Deutsch, Українська]       Не указано
# 992                                 Не указано       Не указано
# 995                                 Не указано       Не указано
# 996                         [Русский, English]  Пастафарианство
# 997                         [Русский, English]       Не указано
# 998                  [English, Eesti, Русский]       Не указано
# 1001                                Не указано       Не указано
# 1014                                Не указано       Не указано
# 1015                                Не указано       Не указано
# 1021                                Не указано       Не указано
# 1023                                Не указано       Не указано
# 1032                                Не указано       Не указано
# 1035                                 [Русский]       Не указано
# 1044                                Не указано       Не указано
# 1048                                Не указано       Не указано
# 1052                                Не указано       Не указано
# 1056                                Не указано       Не указано
# 1071              [Русский, English, Français]      Православие
# 1072                                Не указано       Не указано
# ...                                        ...              ...
# 3671                                 [Русский]       Не указано
# 3674                                Не указано       Не указано
# 3682       [Русский, Українська, English, 日本語]       Не указано
# 3689    [Русский, Українська, English, Türkçe]       Не указано
# 3696                                Не указано       Не указано
# 3697              [Русский, English, Français]       Не указано
# 3716                   [Русский, English, 日本語]       Не указано
# 3718                                Не указано       Не указано
# 3726                                Не указано       Не указано
# 3740                                Не указано       Не указано
# 3759                                Не указано       Не указано
# 3774                                Не указано       Не указано
# 3775                                Не указано       Не указано
# 3778                                 [汉语, 한국어]       Не указано
# 3779                                 [Русский]       Не указано
# 3782                                Не указано       Не указано
# 3792                                Не указано       Не указано
# 3795                        [Русский, English]       Не указано
# 3808                                 [Русский]       Не указано
# 3809                                Не указано       Не указано
# 3816                    [Русский, Къумукъ тил]       Не указано
# 3838                                Не указано       Не указано
# 3840                                Не указано       Не указано
# 3842                        [Русский, English]       Не указано
# 3846  [Русский, English, Українська, Français]       Не указано
# 3851                                 [Русский]       Не указано
# 3854                                Не указано      Православие
# 3865                                Не указано       Не указано
# 3879                                Не указано       Не указано
# 3895                                Не указано       Не указано
#
#                                             inspired_by people_main life_main  \
# 22                                           Не указано  Не указано
# 36                                           Не указано  Не указано
# 74                                           Не указано  Не указано
# 77                                      Все, что вокруг           6
# 139                                          Не указано  Не указано
# 171                                          Не указано  Не указано
# 962                                          Не указано  Не указано
# 964                                          Не указано  Не указано
# 971                                          Не указано  Не указано
# 978                                          Не указано  Не указано
# 986                                          Не указано  Не указано
# 990                                          Не указано           1
# 992                                          Не указано  Не указано
# 995                                          Не указано  Не указано
# 996                           Щеночек и хлебная корочка           1
# 997                                          Не указано  Не указано
# 998                                          Не указано  Не указано
# 1001                                         Не указано  Не указано
# 1014                                         Не указано  Не указано
# 1015                                         Не указано  Не указано
# 1021                                         Не указано  Не указано
# 1023                                         Не указано  Не указано
# 1032                                           МЕМОСИКИ  Не указано
# 1035                                         Не указано  Не указано
# 1044                                         Не указано           2
# 1048                                         Не указано  Не указано
# 1052                                         Не указано  Не указано
# 1056                                         Не указано  Не указано
# 1071                                         Не указано  Не указано
# 1072                                         Не указано  Не указано
# ...                                                 ...         ...       ...
# 3671  Конар, пятое июня, Олежа и Илья, и моя зая🥰❤️💜...           2
# 3674                                         Не указано  Не указано
# 3682                                       Майкл Шинода           5
# 3689                                         Не указано  Не указано
# 3696                                         Не указано  Не указано
# 3697                                    Anastasia ParIS  Не указано
# 3716                                         Не указано           2
# 3718                                         Не указано  Не указано
# 3726                                         Не указано  Не указано
# 3740                                         Не указано  Не указано
# 3759                                         Не указано  Не указано
# 3774                                         Не указано  Не указано
# 3775                                         Не указано  Не указано
# 3778                                         Не указано           3
# 3779                                         Не указано  Не указано
# 3782                                         Не указано  Не указано
# 3792                                         Не указано  Не указано
# 3795                      Сериалы\кино, музыка, поездки           6
# 3808                                         Не указано  Не указано
# 3809                                         Не указано  Не указано
# 3816                                         Не указано  Не указано
# 3838                                         Не указано  Не указано
# 3840                                         Не указано  Не указано
# 3842                                         Не указано           2
# 3846                                         Не указано           2
# 3851                                         Не указано           2
# 3854                                         Не указано           3
# 3865                                         Не указано  Не указано
# 3879                                         Не указано  Не указано
# 3895                                         Не указано  Не указано
#
#          smoking     alcohol  has_facebook  has_instagram  has_livejournal  \
# 22    Не указано  Не указано             0              0                0
# 36    Не указано  Не указано             1              1                0
# 74    Не указано  Не указано             0              0                0
# 77    Не указано  Не указано             0              1                0
# 139   Не указано  Не указано             0              0                0
# 171   Не указано  Не указано             0              0                0
# 962   Не указано  Не указано             0              0                0
# 964   Не указано  Не указано             0              1                0
# 971   Не указано  Не указано             1              0                0
# 978   Не указано  Не указано             0              0                0
# 986   Не указано  Не указано             0              0                0
# 990   Не указано  Не указано             0              1                0
# 992   Не указано  Не указано             1              1                0
# 995   Не указано  Не указано             0              1                0
# 996            2           4             0              1                0
# 997   Не указано  Не указано             0              1                0
# 998   Не указано  Не указано             0              0                0
# 1001  Не указано  Не указано             0              0                0
# 1014  Не указано  Не указано             0              0                0
# 1015  Не указано  Не указано             0              1                0
# 1021  Не указано  Не указано             0              1                0
# 1023  Не указано  Не указано             1              1                0
# 1032           3           5             0              1                0
# 1035  Не указано  Не указано             0              0                0
# 1044           4           4             0              1                0
# 1048  Не указано  Не указано             0              0                0
# 1052  Не указано  Не указано             0              0                0
# 1056  Не указано  Не указано             0              1                0
# 1071           2           2             0              0                0
# 1072  Не указано  Не указано             0              0                0
# ...          ...         ...           ...            ...              ...
# 3671           1  Не указано             0              1                0
# 3674  Не указано  Не указано             0              0                0
# 3682           5  Не указано             0              0                0
# 3689  Не указано  Не указано             0              0                0
# 3696  Не указано  Не указано             0              0                0
# 3697  Не указано  Не указано             0              1                0
# 3716           1  Не указано             0              0                0
# 3718  Не указано  Не указано             0              0                0
# 3726  Не указано  Не указано             0              1                0
# 3740  Не указано  Не указано             0              0                0
# 3759  Не указано  Не указано             0              0                0
# 3774  Не указано  Не указано             0              0                0
# 3775  Не указано  Не указано             0              0                0
# 3778           1  Не указано             0              0                0
# 3779  Не указано  Не указано             0              0                0
# 3782  Не указано  Не указано             0              0                0
# 3792  Не указано  Не указано             0              0                0
# 3795           2           4             0              1                0
# 3808  Не указано  Не указано             0              1                0
# 3809  Не указано  Не указано             0              0                0
# 3816  Не указано  Не указано             0              0                0
# 3838  Не указано  Не указано             0              0                0
# 3840  Не указано  Не указано             0              1                0
# 3842  Не указано  Не указано             0              0                0
# 3846  Не указано  Не указано             1              1                0
# 3851  Не указано  Не указано             0              0                0
# 3854           1           1             0              0                0
# 3865  Не указано  Не указано             0              0                0
# 3879  Не указано  Не указано             0              0                0
# 3895  Не указано  Не указано             0              0                0
#
#       has_twitter  has_skype  has_relative
# 22              0          0             1
# 36              0          0             1
# 74              0          0             1
# 77              0          0             1
# 139             0          0             1
# 171             0          0             1
# 962             0          0             1
# 964             1          0             1
# 971             0          0             1
# 978             0          1             1
# 986             0          0             1
# 990             1          0             1
# 992             1          0             1
# 995             1          0             1
# 996             0          0             1
# 997             0          0             1
# 998             0          0             1
# 1001            0          0             1
# 1014            0          0             1
# 1015            0          0             1
# 1021            1          0             1
# 1023            0          0             1
# 1032            0          0             1
# 1035            0          0             1
# 1044            0          0             1
# 1048            0          0             1
# 1052            0          0             1
# 1056            0          0             1
# 1071            0          0             1
# 1072            1          0             1
# ...           ...        ...           ...
# 3671            0          1             1
# 3674            0          0             1
# 3682            0          0             1
# 3689            0          0             1
# 3696            0          0             1
# 3697            0          0             1
# 3716            0          0             1
# 3718            0          0             1
# 3726            0          0             1
# 3740            0          0             1
# 3759            0          0             1
# 3774            0          0             1
# 3775            0          0             1
# 3778            0          1             1
# 3779            0          0             1
# 3782            0          0             1
# 3792            0          0             1
# 3795            0          0             1
# 3808            0          0             1
# 3809            0          1             1
# 3816            0          1             1
# 3838            0          0             1
# 3840            0          0             1
# 3842            0          0             1
# 3846            1          1             1
# 3851            0          0             1
# 3854            0          0             1
# 3865            0          0             1
# 3879            0          0             1
# 3895            0          0             1
#
# [356 rows x 25 columns]

# %%
def get_avg_completeness(row):
    counter = 0
    #отдельно обрабатываем те столбцы, где отсутствие - это пустая строка или  "Не указано"
    for col in ['about', 'activities', 'books','games','home_town','interests','movies', 'music', 'quotes' ,'political', 'langs', 'religion', 'inspired_by',
       'people_main', 'life_main', 'smoking', 'alcohol']:
        if df[col] != '' and df[col] != 'Не указано':
            counter += 1
    #отдельно обрабатываем числовые признаки
    for col in ['has_mobile','political','relation','has_facebook', 'has_instagram', 'has_livejournal',
       'has_twitter', 'has_skype', 'has_relative']:
        if col != -1 and col != 0:
            counter += 1
    return np.round(counter/len(feat_completeness_lst),2)

# %%
df['avg_completeness'] = df.apply(lambda x: get_avg_completeness(x),axis=1)
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Теперь отдельно выделим длину поста и количество эмоджи в постах в предположении того, что у более молодого поколения больше эмоджи и больше длина постов

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/6c/ee/8cc0af26113508c8513dac40b1990b21d1d0136b3981a8b7b8a231a56c8d/emoji-0.5.2-py3-none-any.whl (41kB)
# Installing collected packages: emoji
# Successfully installed emoji-0.5.2
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install regex
# Out:
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/a6/56/6dcafb42527aa13ea7d0f778a23a03edae20254e89df03a70abc2fc720b6/regex-2019.04.14-cp36-none-win_amd64.whl (321kB)
# Installing collected packages: regex
# Successfully installed regex-2019.4.14
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import regex
import re

# общее число символов в постах
df['post_length'] = df['post'].apply(lambda text: len(text))

# общее число тэгов в постах
def count_tags(text):
    text = ' '.join(text)
    return len(regex.findall('#', text))

df['tags_number'] = df['post'].apply(lambda x: count_tags(x))

# общее число эмоджи в постах
import emoji

def count_emoji(text):
    text = ' '.join(text)
    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return len(emoji_list)

df['emoji_number'] = df['post'].apply(count_emoji)
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['guessed_age'].idxmax()
# Out:
# 22

# %%
df.head()
# Out:
#                                                  about            activities  \
# 22                                                                 Эзотерика
# 36
# 74
# 77   \n\nМОЯ  ГРУППА:\nhttp://vkontakte.ru/club1291...  Импрессионистическая
# 139                                                                  Актриса
#
#     age_cat      bdate                                              books  \
# 22    30_40  18.9.1988  *Анастасия-Влади́мир Мегре́ * Портрет Дориана ...
# 36    30_40   8.2.1989
# 74    30_40       14.3
# 77    30_40                                                       Научные
# 139   30_40  26.4.1989  Секрет, трансерфинг реальности, психология, би...
#
#      can_access_closed                     city  country education_form  \
# 22                True                  Tallinn  Estonia
# 36                True  Dnipropetrovsk (Dnipro)  Ukraine
# 74                True                   Moscow   Russia
# 77                True                     Kyiv  Ukraine
# 139               True                   Moscow   Russia
#
#     education_status faculty_name  followers_count      games  graduation  \
# 22                                          223979                      0
# 36                                          232554                     -1
# 74                                           50692                     -1
# 77                                           49489  Карточные           0
# 139                                          16689                      0
#
#      has_mobile  home_town         id              interests  is_closed  \
# 22            1    Раквере  156432930  фотография, Эзотерика      False
# 36            1               9562528                             False
# 74            1               2801899                             False
# 77            1  Тель-Авив   12113139          Вдохновляющие      False
# 139           1             468500574    Кино, Музыка, спорт      False
#
#            movies     music  occupation  \
# 22                                    0
# 36                                    2
# 74                                    0
# 77   Исторические  Душевная           0
# 139                                   3
#
#                                                 quotes  relation  sex  \
# 22   “In order to experience everyday spirituality,...         0    1
# 36                                                            -1    1
# 74                                                            -1    1
# 77                                                             0    1
# 139                                                            1    1
#
#                                             track_code university_name  \
# 22   8b0ec723Vrcmg8oRplL3-ldLEyUBaAFrvjMXAgXUmhl1l2...
# 36   47a7d04a8ec6VLZTq2TqO_uuQOgIlk85KWcC6wsrDcmVci...
# 74   d83fb197braO8DtNw7wLF_vs7bPMHstqwSkUnCP-VzE2jP...
# 77   6be575180lQ2eXcG9dVYd9z_K6keeWMhxiTkZOi8MTaV1q...
# 139  96e7d5f9fAd7zOsx_4EDw4lvOeSlrmSSEfKd9PmxqPJ-ao...
#
#      verified   political                                  langs    religion  \
# 22          1  Не указано              [English, Eesti, Русский]  Не указано
# 36          0  Не указано                             Не указано  Не указано
# 74          1  Не указано                             Не указано  Не указано
# 77          1           3  [Русский, עברית, English, Українська]  Не указано
# 139         1  Не указано                              [Русский]  Не указано
#
#          inspired_by people_main life_main     smoking     alcohol  \
# 22        Не указано  Не указано            Не указано  Не указано
# 36        Не указано  Не указано            Не указано  Не указано
# 74        Не указано  Не указано            Не указано  Не указано
# 77   Все, что вокруг           6            Не указано  Не указано
# 139       Не указано  Не указано            Не указано  Не указано
#
#     schools_name schools_grad_year  has_facebook  has_instagram  \
# 22                              -1             0              0
# 36                              -1             1              1
# 74                              -1             0              0
# 77                              -1             0              1
# 139                             -1             0              0
#
#      has_livejournal  has_twitter  has_skype  has_relative  \
# 22                 0            0          0             1
# 36                 0            0          0             1
# 74                 0            0          0             1
# 77                 0            0          0             1
# 139                0            0          0             1
#
#                                                   post  guessed_age  \
# 22   [автор, администратор, адрес, бессонный, битва...           31
# 36   [100500, 27🎂всё, abscheck, beautyть, center, c...           30
# 74   [13-ий, 1530, 2017, 2018, 2100, 212vipwildpart...            0
# 77   [1085, 38098, 6-го, annaalkhim, artikselfmad, ...            0
# 139  [-быть, 1200-2100, 1600, 2000, 2011, 2018, 201...           30
#
#      avg_completeness  post_length  tags_number  emoji_number
# 22               0.60          156            0             0
# 36               0.36          429            0            31
# 74               0.36          633            0           173
# 77               0.84          585            0           137
# 139              0.52         1117            0           285

# %% [markdown]
# Готово, теперь оставим только те признаки, которые нам нужны

# %%
df = df[['age_cat','followers_count','sex','post','guessed_age','avg_completeness','post_length','tags_number','emoji_number']].copy()

# %%
df
# Out:
#      age_cat  followers_count  sex  \
# 22     30_40           223979    1
# 36     30_40           232554    1
# 74     30_40            50692    1
# 77     30_40            49489    1
# 139    30_40            16689    1
# 171    30_40            89535    1
# 962    19_30          1312759    1
# 964    19_30           752460    1
# 971    19_30           496395    1
# 978    19_30           462108    1
# 986    19_30           323017    1
# 990    19_30           276108    1
# 992    19_30           368392    1
# 995    19_30           245809    1
# 996    19_30           236053    1
# 997    19_30           231464    1
# 998    19_30           223979    1
# 1001   19_30           219176    1
# 1014   19_30           167244    1
# 1015   19_30           158825    1
# 1021   19_30           139995    1
# 1023   19_30           232554    1
# 1032   19_30           216342    1
# 1035   19_30           114858    1
# 1044   19_30            99659    1
# 1048   19_30            95282    1
# 1052   19_30            85990    1
# 1056   19_30            82898    1
# 1071   19_30           166674    1
# 1072   19_30            64829    1
# ...      ...              ...  ...
# 3671    0_18            13237    1
# 3674    0_18            13441    1
# 3682    0_18            12962    1
# 3689    0_18            13777    1
# 3696    0_18            13513    1
# 3697    0_18            13473    1
# 3716    0_18            12656    1
# 3718    0_18            13510    1
# 3726    0_18            13264    1
# 3740    0_18            12925    1
# 3759    0_18            12669    1
# 3774    0_18            12377    1
# 3775    0_18            12830    1
# 3778    0_18            12785    1
# 3779    0_18            12974    1
# 3782    0_18            13380    1
# 3792    0_18            11986    1
# 3795    0_18            11964    1
# 3808    0_18            11877    1
# 3809    0_18            11872    1
# 3816    0_18            12276    1
# 3838    0_18            12747    1
# 3840    0_18            12554    1
# 3842    0_18            11887    1
# 3846    0_18            11661    1
# 3851    0_18            12260    1
# 3854    0_18            12282    1
# 3865    0_18            12638    1
# 3879    0_18            11706    1
# 3895    0_18            11325    1
#
#                                                    post  guessed_age  \
# 22    [автор, администратор, адрес, бессонный, битва...           31
# 36    [100500, 27🎂всё, abscheck, beautyть, center, c...           30
# 74    [13-ий, 1530, 2017, 2018, 2100, 212vipwildpart...            0
# 77    [1085, 38098, 6-го, annaalkhim, artikselfmad, ...            0
# 139   [-быть, 1200-2100, 1600, 2000, 2011, 2018, 201...           30
# 171   [-agimont, -кожа, -лига, -обратнодинать, -обяз...            0
# 962   [0-10, 10летснюша, 10летснюшейн, 1128, 19-30, ...            0
# 964   [20-ти, 2000, 20000, 2013, 7916675-53-49как, a...            0
# 971   [1745чуть, 1️⃣0️⃣, 2017, 4276300030122025, 471...            0
# 978   [2015ести, ctrl, dashkaegorova, dolc, gabbana,...           22
# 986   [1149, 1200, 1400, 1900, 2100, 3000, alanavenu...            0
# 990   [13-го, 16го, 19-летие, 2017, 2018, 20км, 3сег...           21
# 992   [100м, 1500, 2017, 29052017, among, angelsb, a...            0
# 995   [1200, 2000, 2017, 79689597190, actual, aviapa...           26
# 996   [160000, 1апрель, 2018, 5000, 6000, 8926453444...            0
# 997   [amsterdam, geneva, itali, lookbook, milan, ne...           20
# 998   [автор, администратор, адрес, бессонный, битва...           31
# 1001  [1930, 8-ого, aloneкак, bound, dead, everyth, ...            0
# 1014  [27092016, 5-7кмостановиться, adipiscar🌟🌟🌟судь...            0
# 1015  [10-15, 1717, 19-21, 2000, 2007-, 2008, 2100, ...            0
# 1021  [-ставить, 2018, 2019, 2019💖i, 2019💗новинка, 4...            0
# 1023  [100500, 27🎂всё, abscheck, beautyть, center, c...           30
# 1032  [auroratm, berezka, black, calvin, candi, chuh...           23
# 1035  [-попробовать, -продолжить, 0000, 1200, 1200-1...            0
# 1044  [-междать, -неужель, -приводить, -хороший, 140...           20
# 1048  [agentshow🖤, cinema✍🏼🐜, nahyi, romaзима, пожал...            0
# 1052  [-помнить, -сегодня, 111118, 120918, 1400, 161...           28
# 1056  [1000, 280219, 8март, andreysir, animalplanet,...           26
# 1071  [2013with, 2014, barhat-beauti, bonita, boysво...            0
# 1072  [-challeng, -вызов, -женить, 02052018, 1900, 2...            0
# ...                                                 ...          ...
# 3671                        [5-ий, июня❤️❤️, ❤️вернуть]           16
# 3674                                             [движ]           18
# 3682  [20031976-20072017, alone😩, back, beneath, can...            0
# 3689  [абонемент, ахахах, безразличный, бояться, бра...            0
# 3696                                                 []            0
# 3697  [1маша, 1машанастя, 1❤николь, 1🇪🇸испания, 3маш...            0
# 3716  [безумно…, далеки…, желанны…ный, жить, любимы…...            0
# 3718  [верить, всякий, готовый, демон, долго, думать...            0
# 3726  [crazi, gone, gone⛔🔞онить, head, love❤️сгорать...            0
# 3740                                                 []            0
# 3759  [болит💔сегодний, интернете🕊️, мальчику💔ть, нел...            0
# 3774                                          [девочка]            0
# 3775  [folowmefolowm, folowmeдоброеутро, happi, like...            0
# 3778                                                 []            0
# 3779                     [девушка, мозг🤩❤, сексуальный]            0
# 3782   [boys-кончить, priora, вишнёвый, свелавсё, твой]            0
# 3792  [android, cleaner, cleanervk, commun, friend, ...           17
# 3795  [15-20к, 2019, becom, detroit, human, marvel, ...           16
# 3808  [-моё, aлкоголь, xвaтаять, бoль, ближе🤩, ведат...            0
# 3809  [встрече❌ть, знать, кричать, ладный, мечтать, ...            0
# 3816  [glazah, nikogda, pust, solnc, tvoih, ugasaetн...           19
# 3838  [безногий, быстро, верить, видеть, влюбиться, ...            0
# 3840  [впереди, далеко❤💝всё, ждет🙈❤️❤️❤️мы-дым, нас😌...            0
# 3842                      [закопать, слова💜, 💜💜золотой]           18
# 3846  [вернуться, вечность, встретиться, встреча, вы...           19
# 3851  [dream, fades🕊🌼-, heart, аллах, аллаһ, большег...            0
# 3854  [-почему, -просто, 2359, август, балкон, бесед...           18
# 3865  [-аллах, -всевышний, -ести, -какий, -когда, -к...           18
# 3879  [друзья, заявка, идиот, кидать, людейкоторое, ...           18
# 3895  [artist🇰🇷, call, idol✨потерянный, друг, душа, ...            0
#
#       avg_completeness  post_length  tags_number  emoji_number
# 22                0.60          156            0             0
# 36                0.36          429            0            31
# 74                0.36          633            0           173
# 77                0.84          585            0           137
# 139               0.52         1117            0           285
# 171               0.76         1402            0           120
# 962               0.52         1381            0           190
# 964               0.48          433            0           109
# 971               0.72          635            0            49
# 978               0.48          127            0            15
# 986               0.36          624            0           178
# 990               0.52          748            0            71
# 992               0.36          645            0            12
# 995               0.40          259            0            97
# 996               1.00          517            0           137
# 997               0.44           78            0             4
# 998               0.60          156            0             0
# 1001              0.36          146            0            24
# 1014              0.36          487            0           179
# 1015              0.36          925            0            32
# 1021              0.48          360            0           295
# 1023              0.36          429            0            31
# 1032              0.84          348            0            78
# 1035              0.52          364            0            30
# 1044              0.56          329            0             5
# 1048              0.44            7            0             5
# 1052              0.36         1522            0           106
# 1056              0.36          315            0            38
# 1071              0.60           48            0            28
# 1072              0.36         1127            0            84
# ...                ...          ...          ...           ...
# 3671              0.84            3            0             3
# 3674              0.36            1            0             0
# 3682              0.80           74            0             5
# 3689              0.44          106            0             8
# 3696              0.36            0            0             0
# 3697              0.76          151            0            86
# 3716              0.60           10            0             0
# 3718              0.36           14            0             1
# 3726              0.36           34            0            33
# 3740              0.36            0            0             0
# 3759              0.36            8            0             3
# 3774              0.36            1            0             0
# 3775              0.36           12            0             0
# 3778              0.88            0            0             0
# 3779              0.40            3            0             2
# 3782              0.36            5            0             0
# 3792              0.36           71            0             8
# 3795              0.84          354            0            18
# 3808              0.44           52            0            44
# 3809              0.36           15            0             3
# 3816              0.44           89            0             0
# 3838              0.36           22            0             9
# 3840              0.36            8            0             8
# 3842              0.48            3            0             3
# 3846              0.52           16            0            10
# 3851              0.64           26            0             4
# 3854              0.76          135            0            15
# 3865              0.36          732            0             4
# 3879              0.36            9            0             0
# 3895              0.36           12            0             1
#
# [356 rows x 9 columns]

# %% [markdown]
# Начинаем готовить данные к моделированию

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(df['age_cat'])

# %%
df.drop('age_cat', axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2,  shuffle=True, stratify=y, random_state=121)

# %% [markdown]
# Будем пробовать NaiveBayes LogisticRegression c перебором n_gram_range. Отдельно попробуем CountVectorizer и FTIdfVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def make_post_for_model(df_train, df_test, feature_post, params,CountVect=True ):
    if CountVect:
        vect = CountVectorizer()
        vect.set_params(**params)

        X_tfidf_train = vect.fit_transform(df_train[feature_post])
        X_tfidf_test = vect.transform(df_test[feature_post])
    else:
        vect = TfidfVectorizer()
        vect.set_params(**params)
        
        X_tfidf_train = vect.fit_transform(df_train[feature_post])
        X_tfidf_test = vect.transform(df_test[feature_post])

    return X_tfidf_train, X_tfidf_test

# %%
from sklearn.preprocessing import StandardScaler

# %%
def prepare_model(df_train, df_test, post_train, post_test):
    scaler = StandardScaler()
    df_train_for_model = df_train.drop('post',axis=1)
    df_test_for_model = df_test.drop('post',axis=1)

    X_train_short = pd.DataFrame(data=scaler.fit_transform(df_train_for_model.values), 
                                     index=df_train_for_model.index, 
                                     columns=df_train_for_model.columns)

    X_test_short = pd.DataFrame(data=scaler.transform(df_test_for_model.values), 
                                     index=df_test_for_model.index, 
                                     columns=df_test_for_model.columns)

    X_train_short_sparse = sparse.csr_matrix(X_train_short)
    X_test_short_sparse = sparse.csr_matrix(X_test_short)

    x_train = hstack([X_train_short_sparse, post_train])
    x_test = hstack([X_test_short_sparse, post_test])
    
    return x_train, x_test

# %% [markdown]
# Попробуем биграммы юниграммы триграммы для каждого из векторайзера

# %%
X_train.loc[:,'post'] = X_train['post'].apply(lambda x: ' '.join(x))
X_test.loc[:,'post'] = X_test['post'].apply(lambda x: ' '.join(x))
# Out:
# C:\Users\viktoria.sinditskaya\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
from sklearn.metrics import roc_auc_score

# %%
from sklearn.preprocessing import  LabelBinarizer

# %%
def run_model(model, x_train, x_test, y_train, y_test):
    model.fit(x_train, y_train)
    y_pred_proba = model.predict_proba(x_test)
    y_pred =  model.predict(x_test)
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test_n = lb.transform(y_test)
    y_pred_n = lb.transform(y_pred)
    return (model,roc_auc_score(y_test_n,y_pred_n,average='micro'),accuracy_score(y_test,y_pred))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Результаты будем записывать в таблицу

# %%
table_results = pd.DataFrame(columns=['model_name', 'ROC-AUC' ,
                                     'Accuracy, test'])

# %% [markdown]
# # Naive Bayes

# %%
X_tfidf_train_ngram_1_count_vect, X_tfidf_test_ngram_1_count_vect =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,1), 'analyzer':'word', 'max_features':10000},True )
X_tfidf_train_ngram_2_count_vect, X_tfidf_test_ngram_2_count_vect =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,2), 'analyzer':'word', 'max_features':10000},True )
X_tfidf_train_ngram_3_count_vect, X_tfidf_test_ngram_3_count_vect =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,3), 'analyzer':'word', 'max_features':10000},True )
X_tfidf_train_ngram_3_count_vect_manyfeat, X_tfidf_test_ngram_3_count_vect_manyfeat =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,3), 'analyzer':'word', 'max_features':100000},True )
X_tfidf_train_ngram_1_idf_vect, X_tfidf_test_ngram_1_idf_vect =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,1), 'analyzer':'word', 'max_features':10000},False )
X_tfidf_train_ngram_2_idf_vect, X_tfidf_test_ngram_2_idf_vect =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,2), 'analyzer':'word', 'max_features':10000},False )
X_tfidf_train_ngram_3_idf_vect, X_tfidf_test_ngram_3_idf_vect =  make_post_for_model(X_train, X_test, 'post', {'ngram_range':(1,3), 'analyzer':'word', 'max_features':10000},False )
# Out:
#   File "<ipython-input-411-16020cd51a3e>", line 4
#     for i in range(7):
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
def model_maker(x_train, x_test, y_train, y_test, df_for_results):
    lst_vectorizers = []
    for ngram in [(1,1),(1,2),(1,3)]:
        for bols in [True,False]:
            X_vect_train, X_vect_test = make_post_for_model(x_train, x_test, 'post', {'ngram_range':ngram, 'analyzer':'word', 'max_features':10000},bols )
            lst_vectorizers.append((X_vect_train, X_vect_test))
            name =  "logistic ngram range:{},CountVectorizer is {}".format(ngram,bols)
            df_for_results = df_for_results.append({'model_name' :name,'ROC-AUC':None ,
                                         'Accuracy, test' : None},ignore_index=True)
            
    models_lst = []
    model = LogisticRegression()
    for num,i in enumerate(lst_vectorizers):
        X_vect_train, X_vect_test = i[0],i[1]
        x_train, x_test = prepare_model(X_train, X_test, X_vect_train, X_vect_test )
        model, auc, accuracy = run_model(model, x_train, x_test, y_train, y_test)
        models_lst.append(model)
        df_for_results.loc[num,'ROC-AUC'] = auc
        df_for_results['ROC-AUC'] = df_for_results['ROC-AUC'].astype('float')
        df_for_results.loc[num,'Accuracy, test'] = accuracy
        print(df_for_results)
    best_model_index = df_for_results['ROC-AUC'].idxmax()
    #TODO сохранить табличку с резульататми, а затем протранкейтить 
    return models_lst[best_model_index]

# %%
best_model = model_maker(X_train, X_test, y_train, y_test, table_results)
# Out:
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...       NaN           None
# 2  logistic ngram range:(1, 2),CountVectorizer is...       NaN           None
# 3  logistic ngram range:(1, 2),CountVectorizer is...       NaN           None
# 4  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
# 5  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...  0.864583       0.819444
# 2  logistic ngram range:(1, 2),CountVectorizer is...       NaN           None
# 3  logistic ngram range:(1, 2),CountVectorizer is...       NaN           None
# 4  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
# 5  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...  0.864583       0.819444
# 2  logistic ngram range:(1, 2),CountVectorizer is...  0.812500           0.75
# 3  logistic ngram range:(1, 2),CountVectorizer is...       NaN           None
# 4  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
# 5  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...  0.864583       0.819444
# 2  logistic ngram range:(1, 2),CountVectorizer is...  0.812500           0.75
# 3  logistic ngram range:(1, 2),CountVectorizer is...  0.864583       0.819444
# 4  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
# 5  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...  0.864583       0.819444
# 2  logistic ngram range:(1, 2),CountVectorizer is...  0.812500           0.75
# 3  logistic ngram range:(1, 2),CountVectorizer is...  0.864583       0.819444
# 4  logistic ngram range:(1, 3),CountVectorizer is...  0.812500           0.75
# 5  logistic ngram range:(1, 3),CountVectorizer is...       NaN           None
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...  0.864583       0.819444
# 2  logistic ngram range:(1, 2),CountVectorizer is...  0.812500           0.75
# 3  logistic ngram range:(1, 2),CountVectorizer is...  0.864583       0.819444
# 4  logistic ngram range:(1, 3),CountVectorizer is...  0.812500           0.75
# 5  logistic ngram range:(1, 3),CountVectorizer is...  0.854167       0.805556

# %%
x[1]
# Out:
#                                           model_name   ROC-AUC Accuracy, test
# 0  logistic ngram range:(1, 1),CountVectorizer is...  0.802083       0.736111
# 1  logistic ngram range:(1, 1),CountVectorizer is...  0.864583       0.819444
# 2  logistic ngram range:(1, 2),CountVectorizer is...  0.812500           0.75
# 3  logistic ngram range:(1, 2),CountVectorizer is...  0.864583       0.819444
# 4  logistic ngram range:(1, 3),CountVectorizer is...  0.812500           0.75
# 5  logistic ngram range:(1, 3),CountVectorizer is...  0.854167       0.805556

# %%
table_results.truncate(before=-1, after=-1)
# Out:
# Empty DataFrame
# Columns: [model_name, ROC-AUC, Accuracy, test]
# Index: []

# %%
table_results = table_results.truncate(before=-1, after=-1)

# %%
table_results
# Out:
# Empty DataFrame
# Columns: [model_name, ROC-AUC, Accuracy, test]
# Index: []

# %%
table_results.append({'model_name' :'sd','ROC-AUC':None ,
                                         'Accuracy, test' : None},ignore_index=True)
# Out:
#   model_name   ROC-AUC Accuracy, test
# 0        NaN  0.802083       0.736111
# 1        NaN  0.864583       0.819444
# 2        NaN  0.812500           0.75
# 3        NaN  0.864583       0.819444
# 4        NaN  0.812500           0.75
# 5        NaN  0.854167       0.805556
# 6         sd       NaN           None
